# %%
import pandas as pd
import numpy as np
from find_match import get_top_matches

# %%
# Load user data
df = pd.read_csv('okcupid_profiles_cleaned.csv')

# %%
similarity_df = pd.DataFrame(np.load("similarity_matrix.npy"))

# %%
get_top_matches(0, similarity_df, df,top_n=5)
# Out:
#         age          status     sex orientation       body_type  \
# 28433  21.0          single  female    straight    full figured
# 51769  23.0          single  female    bisexual          jacked
# 58822  22.0  seeing someone  female    bisexual  a little extra
# 15562  21.0          single  female    straight           curvy
# 26993  20.0  seeing someone  female    bisexual        athletic
#
#                   diet       drinks      drugs  \
# 28433         anything     socially  sometimes
# 51769    mostly kosher        often      never
# 58822  mostly anything     socially      never
# 15562   strictly other  desperately      often
# 26993         anything     socially  sometimes
#
#                                education ethnicity  ...             job  \
# 28433  graduated from college/university     white  ...           other
# 51769          graduated from space camp     other  ...  rather not say
# 58822         graduated from high school     white  ...         student
# ...
